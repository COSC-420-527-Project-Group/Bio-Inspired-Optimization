# %%
# using genetic algorithms to optimize simple machine learning models, such 
# as the random forest classifier, to implement brain tumor classification
# using tpot runs thru many models to find the best one
# The dataset used for this model is images of brain tumors available on Kaggle
# https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset
# https://www.geeksforgeeks.org/random-forest-for-image-classification-using-opencv/

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from leap_ec import Individual, ops, util
from leap_ec.algorithm import generational_ea
from leap_ec.decoder import IdentityDecoder
from leap_ec.problem import ScalarProblem
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import os
from PIL import Image
from sklearn.preprocessing import LabelEncoder
from toolz import pipe
from itertools import product
import seaborn as sns

# %%
# --- Genetic Algorithm Parameters ---
POP_SIZE = 25
GENERATIONS = 30
MUTATION_RATE = 0.5
CROSSOVER_RATE = 0.5
TOURNAMENT_SIZES = 5

# --- Hyperparameter search grid ---
n_estimators_options = list(range(50, 200, 1))
max_depth_options = list(range(1, 50, 1))

# %%
# Load Dataset
def load_data(folder_path):
    X = []
    y = []
    for class_name in os.listdir(folder_path):
        class_path = os.path.join(folder_path, class_name)
        if os.path.isdir(class_path):
            for file_name in os.listdir(class_path):
                file_path = os.path.join(class_path, file_name)
                try:
                    img = Image.open(file_path).convert('L') 
                    img = img.resize((64, 64))  
                    img_array = np.array(img).flatten()
                    X.append(img_array)
                    y.append(class_name)
                except Exception as e:
                    print(f"Error loading {file_path}: {e}")
    return np.array(X), np.array(y)

X_train, y_train = load_data('brain_tumor_mri/Training')
X_test, y_test = load_data('brain_tumor_mri/Testing')

# Encode Labels
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# %%
all_combinations = list(product(range(len(n_estimators_options)), range(len(max_depth_options))))

genome_counter = 0
def initialize_hyperparameters():
    global genome_counter
    if genome_counter >= len(all_combinations):
        genome_counter = 0  # or raise StopIteration if you're done
    i, j = all_combinations[genome_counter]
    genome_counter += 1
    return np.array([i, j])

def mutate_integer(population, search_space, p=0.1):
    for individual in population:
        for i, s in enumerate(search_space):
            if np.random.rand() < p:
                individual.genome[i] = np.random.randint(0, len(s))
        # decoded = [search_space[i][gene] for i, gene in enumerate(individual.genome)]
        yield individual

def uniform_crossover(population, p=0.5):
    offspring = []
    it = iter(population)
    for parent1 in it:
        try:
            parent2 = next(it)
        except StopIteration:
            offspring.append(parent1)
            break
        child1_genome = []
        child2_genome = []
        for gene1, gene2 in zip(parent1.genome, parent2.genome):
            if np.random.rand() < p:
                child1_genome.append(gene2)
                child2_genome.append(gene1)
            else:
                child1_genome.append(gene1)
                child2_genome.append(gene2)
        offspring.append(parent1.__class__(child1_genome))
        offspring.append(parent2.__class__(child2_genome))
    return offspring

# %%
fitness_cache = {}
clf = RandomForestClassifier(random_state=42)
class LeapGAProblem(ScalarProblem):
    def __init__(self):
        super().__init__(maximize=True)
        
    def evaluate(self, ind):
        global clf
        n_estimators = n_estimators_options[int(ind[0]) % len(n_estimators_options)]
        max_depth = max_depth_options[int(ind[1]) % len(max_depth_options)]

        key = (n_estimators, max_depth)

        if key in fitness_cache:
            print("Cache hit for key:", key)
            return fitness_cache[key]
        else:
            print("Cache miss for key:", key)

        clf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=42)
        clf.fit(X_train, y_train_encoded)
        y_pred = clf.predict(X_test)
        accuracy = accuracy_score(y_test_encoded, y_pred)
        fitness_cache[key] = accuracy
        return accuracy

# %%
parents = Individual.create_population(POP_SIZE,
                                       initialize=initialize_hyperparameters,
                                       decoder=IdentityDecoder(),
                                       problem=LeapGAProblem())

# %%
parents = Individual.evaluate_population(parents)
# Out:
# Cache miss for key: (50, 1)
# Cache miss for key: (50, 2)
# Cache miss for key: (50, 3)
# Cache miss for key: (50, 4)
# Cache miss for key: (50, 5)
# Cache miss for key: (50, 6)
# Cache miss for key: (50, 7)
# Cache miss for key: (50, 8)
# Cache miss for key: (50, 9)
# Cache miss for key: (50, 10)
# Cache miss for key: (50, 11)
# Cache miss for key: (50, 12)
# Cache miss for key: (50, 13)
# Cache miss for key: (50, 14)
# Cache miss for key: (50, 15)
# Cache miss for key: (50, 16)
# Cache miss for key: (50, 17)
# Cache miss for key: (50, 18)
# Cache miss for key: (50, 19)
# Cache miss for key: (50, 20)
# Cache miss for key: (50, 21)
# Cache miss for key: (50, 22)
# Cache miss for key: (50, 23)
# Cache miss for key: (50, 24)
# Cache miss for key: (50, 25)

# %%
generation_counter = util.inc_generation()
seen_combinations = set()
best_accuracies = []
avg_accuracies = []
log_rows = []

while generation_counter.generation() < GENERATIONS:
    print(f"Working on generation {generation_counter.generation() + 1}")
    offspring = pipe(parents,
                        ops.tournament_selection(k=TOURNAMENT_SIZES),
                        ops.clone,
                        lambda pop: mutate_integer(pop, search_space=[n_estimators_options, max_depth_options], p=MUTATION_RATE),
                        ops.UniformCrossover(p_xover=CROSSOVER_RATE),
                        ops.evaluate,
                        ops.pool(size=len(parents)),  # accumulate offspring
                    )  # increment to the next generation

    best = max(offspring, key=lambda ind: ind.fitness)

    avg_accuracy = np.mean([ind.fitness for ind in offspring])

    best_n_estimators = n_estimators_options[int(best.genome[0]) % len(n_estimators_options)]
    best_max_depth = max_depth_options[int(best.genome[1]) % len(max_depth_options)]

    all_n_estimators = [n_estimators_options[int(ind.genome[0]) % len(n_estimators_options)] for ind in offspring]
    all_max_depths = [max_depth_options[int(ind.genome[1]) % len(max_depth_options)] for ind in offspring]
    avg_n_estimators = np.mean(all_n_estimators)
    avg_max_depth = np.mean(all_max_depths)
    error = 1 - best.fitness
    avg_error = 1 - avg_accuracy

    for ind in offspring:
        n_estimators = n_estimators_options[int(ind.genome[0]) % len(n_estimators_options)]
        max_depth = max_depth_options[int(ind.genome[1]) % len(max_depth_options)]
        seen_combinations.add((n_estimators, max_depth))

    best_accuracies.append(best.fitness)
    avg_accuracies.append(avg_accuracy)

    log_rows.append([
        POP_SIZE,
        MUTATION_RATE,
        CROSSOVER_RATE,
        TOURNAMENT_SIZES,
        generation_counter.generation(),
        best.fitness,
        avg_accuracy,
        best_n_estimators,
        best_max_depth,
        avg_n_estimators,
        avg_max_depth,
        avg_error
    ])

    print(f"log row: {len(log_rows)}")

    parents = offspring
    generation_counter()
# Out:
# Working on generation 1
# Cache miss for key: (122, 8)
# Cache hit for key: (50, 11)
# Cache miss for key: (184, 6)
# Cache miss for key: (169, 26)
# Cache hit for key: (50, 23)
# Cache miss for key: (115, 32)
# Cache miss for key: (197, 19)
# Cache hit for key: (50, 24)
# Cache hit for key: (50, 23)
# Cache hit for key: (50, 22)
# Cache miss for key: (104, 11)
# Cache miss for key: (50, 36)
# Cache miss for key: (118, 43)
# Cache miss for key: (163, 18)
# Cache hit for key: (50, 10)
# Cache miss for key: (107, 23)
# Cache miss for key: (50, 38)
# Cache miss for key: (50, 29)
# Cache hit for key: (50, 4)
# Cache miss for key: (166, 10)
# Cache miss for key: (157, 18)
# Cache miss for key: (73, 38)
# Cache hit for key: (50, 20)
# Cache miss for key: (50, 32)
# Cache hit for key: (50, 25)
# log row: 1
# Working on generation 2
# Cache miss for key: (186, 36)
# Cache hit for key: (50, 36)
# Cache hit for key: (118, 43)
# Cache miss for key: (116, 43)
# Cache miss for key: (71, 26)
# Cache miss for key: (169, 7)
# Cache miss for key: (50, 44)
# Cache hit for key: (50, 32)
# Cache miss for key: (118, 13)
# Cache hit for key: (50, 1)
# Cache miss for key: (118, 40)
# Cache miss for key: (197, 12)
# Cache miss for key: (62, 42)
# Cache miss for key: (118, 5)
# Cache miss for key: (130, 32)
# Cache miss for key: (161, 36)
# Cache miss for key: (104, 29)
# Cache miss for key: (172, 45)
# Cache miss for key: (52, 25)
# Cache miss for key: (169, 22)
# Cache hit for key: (118, 43)
# Cache miss for key: (118, 9)
# Cache miss for key: (68, 26)
# Cache miss for key: (186, 2)
# Cache miss for key: (115, 31)
# log row: 2
# Working on generation 3
# Cache miss for key: (97, 32)
# Cache miss for key: (99, 29)
# Cache hit for key: (118, 43)
# Cache miss for key: (177, 40)
# Cache miss for key: (68, 29)
# Cache miss for key: (116, 10)
# Cache miss for key: (124, 43)
# Cache hit for key: (130, 32)
# Cache miss for key: (116, 8)
# Cache miss for key: (110, 34)
# Cache miss for key: (118, 35)
# Cache miss for key: (153, 25)
# Cache miss for key: (119, 32)
# Cache miss for key: (52, 4)
# Cache miss for key: (121, 7)
# Cache miss for key: (166, 40)
# Cache miss for key: (97, 40)
# Cache miss for key: (197, 27)
# Cache miss for key: (194, 32)
# Cache miss for key: (130, 9)
# Cache miss for key: (72, 46)
# Cache miss for key: (197, 21)
# Cache hit for key: (118, 43)
# Cache miss for key: (116, 23)
# Cache miss for key: (111, 43)
# log row: 3
# Working on generation 4
# Cache hit for key: (118, 43)
# Cache miss for key: (106, 43)
# Cache miss for key: (197, 2)
# Cache miss for key: (145, 19)
# Cache hit for key: (110, 34)
# Cache miss for key: (74, 43)
# Cache miss for key: (76, 43)
# Cache hit for key: (97, 40)
# Cache hit for key: (118, 35)
# Cache miss for key: (119, 36)
# Cache miss for key: (109, 43)
# Cache hit for key: (118, 43)
# Cache hit for key: (197, 21)
# Cache miss for key: (133, 43)
# Cache miss for key: (126, 34)
# Cache hit for key: (118, 35)
# Cache miss for key: (152, 3)
# Cache miss for key: (118, 17)
# Cache miss for key: (180, 27)
# Cache miss for key: (143, 17)
# Cache hit for key: (97, 40)
# Cache hit for key: (111, 43)
# Cache miss for key: (124, 12)
# Cache miss for key: (147, 43)
# Cache miss for key: (188, 43)
# log row: 4
# Working on generation 5
# Cache hit for key: (97, 40)
# Cache miss for key: (159, 40)
# Cache miss for key: (125, 34)
# Cache miss for key: (168, 40)
# Cache hit for key: (118, 40)
# Cache miss for key: (97, 43)
# Cache miss for key: (109, 17)
# Cache hit for key: (118, 35)
# Cache hit for key: (118, 43)
# Cache miss for key: (54, 43)
# Cache miss for key: (126, 1)
# Cache miss for key: (154, 5)
# Cache miss for key: (97, 17)
# Cache miss for key: (119, 11)
# Cache hit for key: (97, 43)
# Cache miss for key: (156, 8)
# Cache hit for key: (97, 40)
# Cache miss for key: (118, 2)
# Cache hit for key: (111, 43)
# Cache miss for key: (121, 43)
# Cache miss for key: (169, 40)
# Cache hit for key: (118, 43)
# Cache miss for key: (98, 43)
# Cache miss for key: (198, 43)
# Cache miss for key: (60, 6)
# log row: 5
# Working on generation 6
# Cache miss for key: (99, 48)
# Cache miss for key: (97, 9)
# Cache miss for key: (75, 43)
# Cache miss for key: (106, 12)
# Cache miss for key: (60, 24)
# Cache miss for key: (97, 46)
# Cache hit for key: (97, 40)
# Cache miss for key: (100, 43)
# Cache miss for key: (118, 30)
# Cache miss for key: (97, 23)
# Cache miss for key: (119, 40)
# Cache miss for key: (93, 21)
# Cache hit for key: (74, 43)
# Cache miss for key: (86, 43)
# Cache miss for key: (126, 33)
# Cache miss for key: (197, 43)
# Cache hit for key: (97, 40)
# Cache hit for key: (97, 40)
# Cache miss for key: (159, 43)
# Cache miss for key: (169, 35)
# Cache miss for key: (167, 40)
# Cache miss for key: (166, 13)
# Cache miss for key: (97, 5)
# Cache miss for key: (186, 32)
# Cache miss for key: (172, 32)
# log row: 6
# Working on generation 7
# Cache hit for key: (126, 33)
# Cache miss for key: (105, 46)
# Cache miss for key: (97, 14)
# Cache miss for key: (75, 40)
# Cache hit for key: (97, 40)
# Cache miss for key: (197, 30)
# Cache hit for key: (119, 40)
# Cache hit for key: (97, 40)
# Cache hit for key: (97, 40)
# Cache hit for key: (97, 46)
# Cache miss for key: (61, 48)
# Cache miss for key: (97, 47)
# Cache miss for key: (119, 20)
# Cache miss for key: (143, 30)
# Cache miss for key: (171, 40)
# Cache miss for key: (180, 23)
# Cache miss for key: (126, 32)
# Cache hit for key: (126, 33)
# Cache miss for key: (97, 48)
# Cache miss for key: (53, 40)
# Cache miss for key: (108, 10)
# Cache miss for key: (117, 40)
# Cache miss for key: (100, 19)
# Cache miss for key: (118, 38)
# Cache miss for key: (99, 14)
# log row: 7
# Working on generation 8
# Cache miss for key: (159, 49)
# Cache miss for key: (78, 28)
# Cache miss for key: (109, 8)
# Cache miss for key: (97, 33)
# Cache hit for key: (97, 48)
# Cache miss for key: (125, 45)
# Cache hit for key: (118, 43)
# Cache hit for key: (97, 40)
# Cache miss for key: (126, 36)
# Cache hit for key: (126, 36)
# Cache hit for key: (97, 40)
# Cache miss for key: (126, 41)
# Cache miss for key: (137, 9)
# Cache hit for key: (126, 33)
# Cache miss for key: (176, 48)
# Cache hit for key: (97, 47)
# Cache miss for key: (119, 18)
# Cache miss for key: (86, 44)
# Cache miss for key: (97, 45)
# Cache miss for key: (172, 49)
# Cache miss for key: (132, 40)
# Cache hit for key: (119, 40)
# Cache miss for key: (133, 6)
# Cache miss for key: (101, 47)
# Cache miss for key: (156, 40)
# log row: 8
# Working on generation 9
# Cache miss for key: (181, 43)
# Cache hit for key: (97, 40)
# Cache miss for key: (126, 14)
# Cache hit for key: (126, 36)
# Cache hit for key: (126, 32)
# Cache miss for key: (162, 36)
# Cache miss for key: (119, 27)
# Cache hit for key: (97, 40)
# Cache miss for key: (51, 47)
# Cache miss for key: (194, 48)
# Cache hit for key: (119, 40)
# Cache hit for key: (126, 41)
# Cache miss for key: (151, 35)
# Cache miss for key: (78, 41)
# Cache miss for key: (162, 41)
# Cache miss for key: (140, 45)
# Cache miss for key: (180, 33)
# Cache miss for key: (118, 26)
# Cache hit for key: (118, 40)
# Cache miss for key: (128, 31)
# Cache miss for key: (93, 48)
# Cache miss for key: (171, 37)
# Cache miss for key: (71, 45)
# Cache miss for key: (132, 41)
# Cache miss for key: (179, 43)
# log row: 9
# Working on generation 10
# Cache miss for key: (194, 41)
# Cache hit for key: (97, 40)
# Cache hit for key: (97, 40)
# Cache miss for key: (85, 28)
# Cache miss for key: (97, 24)
# Cache miss for key: (56, 40)
# Cache miss for key: (180, 48)
# Cache hit for key: (97, 40)
# Cache hit for key: (97, 40)
# Cache miss for key: (55, 40)
# Cache miss for key: (50, 33)
# Cache hit for key: (126, 36)
# Cache hit for key: (126, 41)
# Cache miss for key: (119, 48)
# Cache miss for key: (93, 40)
# Cache hit for key: (118, 40)
# Cache miss for key: (127, 36)
# Cache miss for key: (74, 40)
# Cache hit for key: (126, 41)
# Cache hit for key: (126, 41)
# Cache miss for key: (130, 40)
# Cache miss for key: (84, 9)
# Cache miss for key: (198, 38)
# Cache miss for key: (137, 17)
# Cache miss for key: (140, 41)
# log row: 10
# Working on generation 11
# Cache miss for key: (102, 40)
# Cache hit for key: (85, 28)
# Cache miss for key: (120, 36)
# Cache miss for key: (194, 1)
# Cache miss for key: (165, 40)
# Cache miss for key: (150, 8)
# Cache miss for key: (180, 40)
# Cache hit for key: (140, 41)
# Cache miss for key: (94, 40)
# Cache miss for key: (126, 6)
# Cache miss for key: (161, 32)
# Cache hit for key: (126, 41)
# Cache miss for key: (185, 1)
# Cache miss for key: (134, 48)
# Cache hit for key: (130, 40)
# Cache miss for key: (126, 26)
# Cache miss for key: (124, 30)
# Cache miss for key: (185, 41)
# Cache hit for key: (97, 40)
# Cache miss for key: (182, 33)
# Cache miss for key: (98, 30)
# Cache hit for key: (97, 40)
# Cache miss for key: (199, 15)
# Cache hit for key: (118, 40)
# Cache hit for key: (119, 48)
# log row: 11
# Working on generation 12
# Cache hit for key: (118, 26)
# Cache miss for key: (85, 27)
# Cache hit for key: (97, 40)
# Cache miss for key: (134, 40)
# Cache miss for key: (118, 8)
# Cache hit for key: (97, 40)
# Cache miss for key: (97, 26)
# Cache hit for key: (94, 40)
# Cache hit for key: (97, 46)
# Cache miss for key: (183, 49)
# Cache miss for key: (122, 28)
# Cache hit for key: (126, 36)
# Cache hit for key: (130, 40)
# Cache hit for key: (130, 40)
# Cache miss for key: (89, 40)
# Cache hit for key: (120, 36)
# Cache hit for key: (97, 40)
# Cache miss for key: (65, 9)
# Cache hit for key: (134, 48)
# Cache miss for key: (119, 49)
# Cache miss for key: (124, 19)
# Cache miss for key: (82, 40)
# Cache hit for key: (97, 40)
# Cache miss for key: (116, 12)
# Cache miss for key: (126, 40)
# log row: 12
# Working on generation 13
# Cache hit for key: (117, 40)
# Cache miss for key: (97, 13)
# Cache hit for key: (85, 27)
# Cache hit for key: (97, 40)
# Cache hit for key: (169, 40)
# Cache miss for key: (88, 28)
# Cache hit for key: (126, 40)
# Cache miss for key: (61, 46)
# Cache miss for key: (170, 20)
# Cache hit for key: (97, 40)
# Cache hit for key: (97, 46)
# Cache miss for key: (94, 22)
# Cache miss for key: (97, 18)
# Cache hit for key: (97, 45)
# Cache miss for key: (124, 25)
# Cache miss for key: (126, 22)
# Cache miss for key: (97, 21)
# Cache hit for key: (97, 40)
# Cache miss for key: (93, 25)
# Cache hit for key: (167, 40)
# Cache miss for key: (66, 31)
# Cache miss for key: (162, 39)
# Cache hit for key: (97, 32)
# Cache hit for key: (97, 40)
# Cache miss for key: (70, 36)
# log row: 13
# Working on generation 14
# Cache miss for key: (134, 31)
# Cache miss for key: (81, 40)
# Cache hit for key: (97, 40)
# Cache miss for key: (199, 40)
# Cache miss for key: (190, 25)
# Cache miss for key: (126, 4)
# Cache hit for key: (162, 39)
# Cache miss for key: (101, 26)
# Cache miss for key: (163, 14)
# Cache hit for key: (170, 20)
# Cache miss for key: (197, 40)
# Cache miss for key: (174, 32)
# Cache miss for key: (117, 38)
# Cache miss for key: (74, 27)
# Cache miss for key: (196, 9)
# Cache hit for key: (97, 45)
# Cache miss for key: (79, 47)
# Cache hit for key: (97, 24)
# Cache miss for key: (165, 27)
# Cache hit for key: (97, 43)
# Cache miss for key: (52, 13)
# Cache miss for key: (121, 29)
# Cache miss for key: (97, 31)
# Cache miss for key: (68, 40)
# Cache miss for key: (125, 15)
# log row: 14
# Working on generation 15
# Cache miss for key: (157, 17)
# Cache hit for key: (97, 43)
# Cache miss for key: (128, 40)
# Cache hit for key: (97, 46)
# Cache hit for key: (97, 45)
# Cache miss for key: (106, 42)
# Cache miss for key: (121, 39)
# Cache hit for key: (169, 40)
# Cache miss for key: (121, 37)
# Cache miss for key: (81, 7)
# Cache hit for key: (97, 31)
# Cache hit for key: (93, 48)
# Cache miss for key: (74, 37)
# Cache miss for key: (187, 38)
# Cache miss for key: (167, 36)
# Cache miss for key: (173, 43)
# Cache miss for key: (68, 31)
# Cache hit for key: (97, 13)
# Cache miss for key: (146, 19)
# Cache miss for key: (71, 46)
# Cache hit for key: (134, 31)
# Cache miss for key: (129, 14)
# Cache miss for key: (122, 43)
# Cache miss for key: (57, 38)
# Cache miss for key: (149, 21)
# log row: 15
# Working on generation 16
# Cache miss for key: (97, 12)
# Cache hit for key: (97, 45)
# Cache miss for key: (60, 16)
# Cache miss for key: (122, 31)
# Cache miss for key: (122, 12)
# Cache miss for key: (122, 37)
# Cache miss for key: (148, 43)
# Cache miss for key: (97, 37)
# Cache miss for key: (97, 1)
# Cache miss for key: (160, 46)
# Cache hit for key: (128, 40)
# Cache hit for key: (97, 46)
# Cache hit for key: (97, 40)
# Cache miss for key: (51, 42)
# Cache miss for key: (122, 4)
# Cache miss for key: (97, 27)
# Cache miss for key: (134, 19)
# Cache miss for key: (134, 45)
# Cache miss for key: (51, 31)
# Cache miss for key: (187, 47)
# Cache miss for key: (113, 12)
# Cache hit for key: (97, 1)
# Cache miss for key: (143, 41)
# Cache hit for key: (122, 43)
# Cache miss for key: (106, 5)
# log row: 16
# Working on generation 17
# Cache miss for key: (118, 37)
# Cache miss for key: (164, 27)
# Cache miss for key: (63, 21)
# Cache hit for key: (122, 43)
# Cache miss for key: (165, 49)
# Cache hit for key: (97, 27)
# Cache hit for key: (122, 43)
# Cache miss for key: (127, 31)
# Cache miss for key: (122, 13)
# Cache hit for key: (97, 46)
# Cache miss for key: (174, 26)
# Cache miss for key: (181, 37)
# Cache miss for key: (51, 45)
# Cache hit for key: (128, 40)
# Cache hit for key: (134, 45)
# Cache hit for key: (97, 46)
# Cache hit for key: (97, 27)
# Cache hit for key: (97, 33)
# Cache miss for key: (138, 26)
# Cache miss for key: (97, 34)
# Cache hit for key: (106, 12)
# Cache miss for key: (131, 45)
# Cache miss for key: (97, 42)
# Cache miss for key: (177, 21)
# Cache miss for key: (89, 13)
# log row: 17
# Working on generation 18
# Cache hit for key: (97, 40)
# Cache miss for key: (122, 45)
# Cache miss for key: (127, 8)
# Cache hit for key: (97, 46)
# Cache hit for key: (131, 45)
# Cache miss for key: (176, 24)
# Cache miss for key: (55, 48)
# Cache hit for key: (97, 46)
# Cache miss for key: (97, 11)
# Cache miss for key: (178, 21)
# Cache miss for key: (122, 27)
# Cache miss for key: (131, 30)
# Cache miss for key: (79, 38)
# Cache hit for key: (97, 46)
# Cache hit for key: (97, 27)
# Cache miss for key: (96, 49)
# Cache hit for key: (127, 31)
# Cache hit for key: (97, 46)
# Cache miss for key: (186, 40)
# Cache hit for key: (97, 1)
# Cache miss for key: (97, 3)
# Cache miss for key: (75, 2)
# Cache miss for key: (83, 31)
# Cache hit for key: (97, 27)
# Cache hit for key: (131, 45)
# log row: 18
# Working on generation 19
# Cache miss for key: (76, 47)
# Cache miss for key: (145, 40)
# Cache miss for key: (74, 49)
# Cache miss for key: (96, 45)
# Cache hit for key: (97, 46)
# Cache miss for key: (125, 46)
# Cache miss for key: (122, 24)
# Cache miss for key: (197, 31)
# Cache miss for key: (97, 15)
# Cache hit for key: (97, 21)
# Cache miss for key: (135, 40)
# Cache hit for key: (97, 46)
# Cache miss for key: (121, 45)
# Cache hit for key: (97, 27)
# Cache miss for key: (155, 45)
# Cache miss for key: (163, 45)
# Cache hit for key: (134, 40)
# Cache miss for key: (186, 49)
# Cache hit for key: (97, 31)
# Cache miss for key: (127, 9)
# Cache hit for key: (97, 21)
# Cache miss for key: (88, 46)
# Cache miss for key: (127, 11)
# Cache miss for key: (172, 35)
# Cache miss for key: (192, 42)
# log row: 19
# Working on generation 20
# Cache miss for key: (134, 44)
# Cache hit for key: (97, 27)
# Cache miss for key: (96, 31)
# Cache miss for key: (137, 31)
# Cache miss for key: (170, 40)
# Cache miss for key: (134, 46)
# Cache hit for key: (89, 40)
# Cache hit for key: (97, 42)
# Cache miss for key: (137, 33)
# Cache hit for key: (96, 45)
# Cache hit for key: (66, 31)
# Cache miss for key: (115, 27)
# Cache miss for key: (110, 46)
# Cache miss for key: (53, 49)
# Cache miss for key: (163, 48)
# Cache hit for key: (97, 31)
# Cache miss for key: (97, 28)
# Cache hit for key: (97, 46)
# Cache miss for key: (177, 8)
# Cache hit for key: (125, 46)
# Cache miss for key: (108, 40)
# Cache hit for key: (97, 46)
# Cache hit for key: (97, 31)
# Cache miss for key: (134, 47)
# Cache miss for key: (74, 46)
# log row: 20
# Working on generation 21
# Cache miss for key: (144, 42)
# Cache hit for key: (97, 46)
# Cache miss for key: (107, 46)
# Cache miss for key: (59, 32)
# Cache miss for key: (97, 16)
# Cache miss for key: (87, 49)
# Cache hit for key: (110, 46)
# Cache hit for key: (50, 1)
# Cache miss for key: (135, 46)
# Cache miss for key: (101, 25)
# Cache hit for key: (125, 46)
# Cache miss for key: (70, 46)
# Cache hit for key: (97, 31)
# Cache miss for key: (146, 40)
# Cache hit for key: (97, 31)
# Cache miss for key: (97, 49)
# Cache hit for key: (94, 40)
# Cache hit for key: (97, 40)
# Cache miss for key: (117, 46)
# Cache miss for key: (152, 29)
# Cache miss for key: (178, 8)
# Cache hit for key: (97, 31)
# Cache miss for key: (97, 41)
# Cache miss for key: (90, 31)
# Cache miss for key: (86, 2)
# log row: 21
# Working on generation 22
# Cache hit for key: (97, 31)
# Cache hit for key: (97, 40)
# Cache miss for key: (120, 21)
# Cache miss for key: (54, 40)
# Cache hit for key: (196, 9)
# Cache miss for key: (101, 17)
# Cache miss for key: (59, 46)
# Cache miss for key: (117, 7)
# Cache miss for key: (169, 19)
# Cache miss for key: (97, 20)
# Cache hit for key: (97, 46)
# Cache miss for key: (159, 6)
# Cache miss for key: (144, 31)
# Cache miss for key: (120, 31)
# Cache miss for key: (150, 49)
# Cache miss for key: (97, 38)
# Cache miss for key: (170, 27)
# Cache hit for key: (97, 20)
# Cache miss for key: (115, 49)
# Cache hit for key: (97, 31)
# Cache miss for key: (93, 46)
# Cache miss for key: (173, 31)
# Cache hit for key: (97, 31)
# Cache hit for key: (97, 41)
# Cache hit for key: (97, 40)
# log row: 22
# Working on generation 23
# Cache hit for key: (97, 13)
# Cache hit for key: (130, 40)
# Cache miss for key: (166, 31)
# Cache hit for key: (122, 31)
# Cache hit for key: (97, 23)
# Cache hit for key: (59, 46)
# Cache miss for key: (164, 31)
# Cache miss for key: (97, 29)
# Cache hit for key: (97, 31)
# Cache miss for key: (97, 10)
# Cache miss for key: (97, 7)
# Cache hit for key: (97, 15)
# Cache miss for key: (76, 31)
# Cache hit for key: (97, 40)
# Cache hit for key: (97, 15)
# Cache hit for key: (97, 31)
# Cache miss for key: (111, 31)
# Cache miss for key: (108, 20)
# Cache miss for key: (152, 48)
# Cache miss for key: (120, 24)
# Cache hit for key: (97, 31)
# Cache hit for key: (97, 12)
# Cache miss for key: (155, 10)
# Cache hit for key: (97, 21)
# Cache miss for key: (166, 3)
# log row: 23
# Working on generation 24
# Cache hit for key: (97, 31)
# Cache miss for key: (97, 6)
# Cache miss for key: (111, 49)
# Cache miss for key: (161, 31)
# Cache miss for key: (103, 26)
# Cache hit for key: (97, 31)
# Cache hit for key: (170, 27)
# Cache miss for key: (60, 31)
# Cache miss for key: (188, 37)
# Cache hit for key: (144, 31)
# Cache miss for key: (149, 49)
# Cache hit for key: (97, 31)
# Cache miss for key: (181, 46)
# Cache hit for key: (97, 31)
# Cache miss for key: (140, 43)
# Cache miss for key: (166, 17)
# Cache hit for key: (166, 31)
# Cache hit for key: (97, 11)
# Cache miss for key: (97, 2)
# Cache miss for key: (97, 19)
# Cache hit for key: (97, 31)
# Cache hit for key: (122, 31)
# Cache hit for key: (166, 13)
# Cache miss for key: (154, 31)
# Cache miss for key: (193, 31)
# log row: 24
# Working on generation 25
# Cache miss for key: (97, 25)
# Cache miss for key: (170, 31)
# Cache miss for key: (125, 23)
# Cache miss for key: (97, 44)
# Cache miss for key: (154, 33)
# Cache miss for key: (178, 26)
# Cache hit for key: (60, 31)
# Cache miss for key: (122, 15)
# Cache hit for key: (170, 27)
# Cache hit for key: (97, 31)
# Cache miss for key: (122, 2)
# Cache hit for key: (97, 1)
# Cache hit for key: (97, 31)
# Cache hit for key: (97, 31)
# Cache miss for key: (194, 49)
# Cache miss for key: (199, 1)
# Cache hit for key: (96, 31)
# Cache hit for key: (97, 31)
# Cache miss for key: (97, 39)
# Cache miss for key: (181, 31)
# Cache miss for key: (122, 5)
# Cache miss for key: (139, 18)
# Cache miss for key: (151, 31)
# Cache miss for key: (61, 31)
# Cache miss for key: (161, 9)
# log row: 25
# Working on generation 26
# Cache hit for key: (96, 31)
# Cache hit for key: (97, 44)
# Cache hit for key: (76, 31)
# Cache miss for key: (154, 43)
# Cache hit for key: (97, 31)
# Cache miss for key: (97, 22)
# Cache miss for key: (199, 10)
# Cache hit for key: (97, 38)
# Cache miss for key: (139, 26)
# Cache miss for key: (176, 31)
# Cache miss for key: (146, 16)
# Cache hit for key: (97, 46)
# Cache miss for key: (199, 12)
# Cache miss for key: (78, 26)
# Cache hit for key: (97, 38)
# Cache hit for key: (97, 11)
# Cache miss for key: (111, 33)
# Cache hit for key: (97, 26)
# Cache hit for key: (97, 3)
# Cache miss for key: (87, 39)
# Cache miss for key: (160, 43)
# Cache miss for key: (62, 31)
# Cache hit for key: (97, 31)
# Cache hit for key: (97, 31)
# Cache hit for key: (97, 18)
# log row: 26
# Working on generation 27
# Cache hit for key: (97, 38)
# Cache hit for key: (199, 40)
# Cache hit for key: (97, 38)
# Cache hit for key: (96, 49)
# Cache hit for key: (97, 43)
# Cache miss for key: (76, 30)
# Cache miss for key: (86, 46)
# Cache miss for key: (166, 33)
# Cache miss for key: (71, 9)
# Cache hit for key: (97, 38)
# Cache hit for key: (97, 31)
# Cache miss for key: (98, 36)
# Cache miss for key: (135, 4)
# Cache miss for key: (120, 26)
# Cache hit for key: (166, 31)
# Cache hit for key: (97, 20)
# Cache hit for key: (97, 38)
# Cache miss for key: (56, 29)
# Cache miss for key: (97, 35)
# Cache miss for key: (95, 46)
# Cache hit for key: (97, 31)
# Cache miss for key: (54, 31)
# Cache miss for key: (65, 34)
# Cache hit for key: (97, 7)
# Cache miss for key: (130, 31)
# log row: 27
# Working on generation 28
# Cache hit for key: (97, 38)
# Cache miss for key: (57, 16)
# Cache miss for key: (189, 32)
# Cache hit for key: (97, 38)
# Cache hit for key: (97, 19)
# Cache miss for key: (152, 35)
# Cache hit for key: (97, 23)
# Cache hit for key: (97, 31)
# Cache hit for key: (97, 31)
# Cache hit for key: (97, 2)
# Cache miss for key: (180, 38)
# Cache miss for key: (168, 38)
# Cache hit for key: (97, 45)
# Cache hit for key: (97, 14)
# Cache miss for key: (95, 4)
# Cache hit for key: (97, 12)
# Cache miss for key: (95, 24)
# Cache hit for key: (97, 14)
# Cache hit for key: (57, 38)
# Cache hit for key: (97, 48)
# Cache hit for key: (97, 38)
# Cache hit for key: (168, 38)
# Cache miss for key: (95, 11)
# Cache hit for key: (97, 5)
# Cache hit for key: (97, 31)
# log row: 28
# Working on generation 29
# Cache miss for key: (177, 22)
# Cache miss for key: (169, 38)
# Cache hit for key: (97, 38)
# Cache miss for key: (94, 38)
# Cache hit for key: (97, 7)
# Cache miss for key: (115, 8)
# Cache miss for key: (101, 38)
# Cache hit for key: (97, 43)
# Cache hit for key: (97, 38)
# Cache miss for key: (101, 45)
# Cache miss for key: (110, 31)
# Cache miss for key: (91, 17)
# Cache hit for key: (97, 10)
# Cache hit for key: (97, 31)
# Cache hit for key: (97, 28)
# Cache hit for key: (97, 38)
# Cache miss for key: (69, 45)
# Cache miss for key: (125, 48)
# Cache hit for key: (97, 17)
# Cache hit for key: (97, 14)
# Cache hit for key: (197, 19)
# Cache miss for key: (67, 29)
# Cache hit for key: (137, 9)
# Cache miss for key: (191, 31)
# Cache hit for key: (97, 38)
# log row: 29
# Working on generation 30
# Cache miss for key: (114, 48)
# Cache hit for key: (101, 45)
# Cache miss for key: (164, 48)
# Cache miss for key: (119, 19)
# Cache miss for key: (81, 27)
# Cache miss for key: (64, 38)
# Cache hit for key: (97, 24)
# Cache hit for key: (110, 31)
# Cache miss for key: (103, 38)
# Cache hit for key: (97, 1)
# Cache miss for key: (188, 30)
# Cache miss for key: (110, 38)
# Cache miss for key: (93, 49)
# Cache miss for key: (72, 31)
# Cache hit for key: (97, 38)
# Cache miss for key: (188, 45)
# Cache hit for key: (97, 1)
# Cache miss for key: (114, 15)
# Cache hit for key: (67, 29)
# Cache miss for key: (62, 43)
# Cache hit for key: (97, 2)
# Cache miss for key: (181, 8)
# Cache miss for key: (69, 43)
# Cache hit for key: (155, 10)
# Cache miss for key: (126, 38)
# log row: 30

# %%
plt.plot(range(GENERATIONS), best_accuracies, marker='o')
plt.title('Best Accuracy per Generation')
plt.xlabel('Generation')
plt.ylabel('Accuracy')
plt.grid()
plt.show()

# %%
plt.plot(range(GENERATIONS), avg_accuracies, marker='o')
plt.title('Avg Accuracy per Generation')
plt.xlabel('Generation')
plt.ylabel('Accuracy')
plt.grid()
plt.show()

# %%
with open("RF_LEAP_GA_25_cm_results.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Population", "Mutation_rate", "Crossover_rate", "tournament_size", "Generation", "Best_Accuracy", "Average_Accuracy", "Best_n_estimators", "Best_max_depth", "Avg_n_estimators", "Avg_max_depth", "Error_avg_accuracy"])
    writer.writerows(log_rows)

# %%
y_pred = clf.predict(X_test)
cm = confusion_matrix(y_test_encoded, y_pred)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_,
            yticklabels=le.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
